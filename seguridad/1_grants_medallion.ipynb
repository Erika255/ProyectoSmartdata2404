# %% [markdown]
# ## Grants

# %%
# %sql
-- GRANT al catalog
GRANT USE CATALOG ON CATALOG catalog_clinica TO `esymi2021ed@gmail.com`;

# %%
# %sql
-- GRANTS en schemas
GRANT USE SCHEMA ON SCHEMA catalog_clinica.bronze TO `esymi2021ed@gmail.com`;
GRANT USE SCHEMA ON SCHEMA catalog_clinica.silver TO `esymi2021ed@gmail.com`;
GRANT USE SCHEMA ON SCHEMA catalog_clinica.golden TO `esymi2021ed@gmail.com`;

# %%
# %sql
-- GRANTS de creación en schemas
GRANT CREATE TABLE ON SCHEMA catalog_clinica.bronze TO `esymi2021ed@gmail.com`;
GRANT CREATE TABLE ON SCHEMA catalog_clinica.silver TO `esymi2021ed@gmail.com`;
GRANT CREATE TABLE ON SCHEMA catalog_clinica.golden TO `esymi2021ed@gmail.com`;

# %%
# %sql
-- GRANTS en tablas bronze
GRANT SELECT ON TABLE catalog_clinica.bronze.citas TO `esymi2021ed@gmail.com`;
GRANT SELECT ON TABLE catalog_clinica.bronze.pacientes TO `esymi2021ed@gmail.com`;
GRANT SELECT ON TABLE catalog_clinica.bronze.medicos TO `esymi2021ed@gmail.com`;
GRANT SELECT ON TABLE catalog_clinica.bronze.especialidades TO `esymi2021ed@gmail.com`;
GRANT SELECT ON TABLE catalog_clinica.bronze.atenciones TO `esymi2021ed@gmail.com`;
GRANT SELECT ON TABLE catalog_clinica.bronze.pagos TO `esymi2021ed@gmail.com`;

# %%
# %sql
-- GRANTS en tablas silver
GRANT SELECT ON TABLE catalog_clinica.silver.citas_detalle TO `esymi2021ed@gmail.com`;
GRANT SELECT ON TABLE catalog_clinica.silver.atenciones_detalle TO `esymi2021ed@gmail.com`;

# %%
# %sql
-- GRANTS en tablas golden
GRANT SELECT ON TABLE catalog_clinica.golden.desercion_por_especialidad TO `esymi2021ed@gmail.com`;
GRANT SELECT ON TABLE catalog_clinica.golden.desercion_por_seguro TO `esymi2021ed@gmail.com`;
GRANT SELECT ON TABLE catalog_clinica.golden.ingresos_por_especialidad TO `esymi2021ed@gmail.com`;
GRANT SELECT ON TABLE catalog_clinica.golden.pacientes_recurrentes TO `esymi2021ed@gmail.com`;

# %%
# %sql
-- Crear grupo y agregar usuario
CREATE GROUP `data_engineers_clinica`;
ALTER GROUP `data_engineers_clinica` ADD USER `esymi2021ed@gmail.com`;

# %%
# %sql
-- GRANTS al grupo
GRANT USE CATALOG ON CATALOG catalog_clinica TO `data_engineers_clinica`;
GRANT USE SCHEMA ON SCHEMA catalog_clinica.bronze TO `data_engineers_clinica`;
GRANT USE SCHEMA ON SCHEMA catalog_clinica.silver TO `data_engineers_clinica`;
GRANT USE SCHEMA ON SCHEMA catalog_clinica.golden TO `data_engineers_clinica`;

# %%
# %sql
-- GRANTS en external locations
GRANT READ FILES ON EXTERNAL LOCATION `extl-raw` TO `esymi2021ed@gmail.com`;
GRANT ALL PRIVILEGES ON EXTERNAL LOCATION `extl-bronze` TO `esymi2021ed@gmail.com`;
GRANT ALL PRIVILEGES ON EXTERNAL LOCATION `extl-silver` TO `esymi2021ed@gmail.com`;
GRANT ALL PRIVILEGES ON EXTERNAL LOCATION `extl-golden` TO `esymi2021ed@gmail.com`;

# %%
# %sql
-- Verificar grants
SHOW GRANTS ON CATALOG catalog_clinica;

# %%
SHOW USERS;
