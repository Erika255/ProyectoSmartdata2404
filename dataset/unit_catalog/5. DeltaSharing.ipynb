-- %%
select * from catalog_ut_smartdata.golden.kpis_ventas

-- %%
CREATE SHARE VENTAS_SHARE

-- %%
SHOW SHARES

-- %%
ALTER SHARE VENTAS_SHARE 
ADD TABLE catalog_ut_smartdata.golden.kpis_ventas
WITH HISTORY

-- %%
CREATE RECIPIENT ExternalCompanys

-- %%
GRANT SELECT 
ON SHARE VENTAS_SHARE
TO RECIPIENT ExternalCompanys
